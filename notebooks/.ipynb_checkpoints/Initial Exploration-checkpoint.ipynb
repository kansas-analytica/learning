# %%
import pandas as pd
import numpy as np
from textblob import TextBlob
from sklearn.preprocessing import LabelEncoder

# %%
df1 = pd.read_csv('../data/1.csv', error_bad_lines=False)
df2 = pd.read_csv('../data/3.csv', error_bad_lines=False)
df = pd.concat([df1, df2])
df.fillna(value = 0.0, inplace = True)
print(df.dtypes)
print("Shape: {}".format(df.shape))
# add some weak NLP stuff 
df[['polarity', 'subjectivity']] = df['content'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
df.head(10)
# Out:
# external_author_id      int64
# author                 object
# content                object
# region                 object
# language               object
# publish_date           object
# harvested_date         object
# following             float64
# followers             float64
# updates               float64
# post_type              object
# account_type           object
# retweet               float64
# account_category       object
# new_june_2018         float64
# alt_external_id       float64
# tweet_id              float64
# article_url            object
# tco1_step1             object
# tco2_step1             object
# tco3_step1             object
# dtype: object
# Shape: (5188, 21)
#    external_author_id  author  \
# 0  906000000000000000  10_GOP
# 1  906000000000000000  10_GOP
# 2  906000000000000000  10_GOP
# 3  906000000000000000  10_GOP
# 4  906000000000000000  10_GOP
# 5  906000000000000000  10_GOP
# 6  906000000000000000  10_GOP
# 7  906000000000000000  10_GOP
# 8  906000000000000000  10_GOP
# 9  906000000000000000  10_GOP
#
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3  JUST IN: President Trump dedicates Presidents ...  Unknown  English
# 4  19,000 RESPECTING our National Anthem! #StandF...  Unknown  English
# 5  Dan Bongino: "Nobody trolls liberals better th...  Unknown  English
# 6                        🐝🐝🐝 https://t.co/MorL3AQW0z  Unknown  English
# 7  '@SenatorMenendez @CarmenYulinCruz Doesn't mat...  Unknown  English
# 8  As much as I hate promoting CNN article, here ...  Unknown  English
# 9  After the 'genocide' remark from San Juan Mayo...  Unknown  English
#
#       publish_date   harvested_date  following  followers  updates  ...  \
# 0  10/1/2017 19:58  10/1/2017 19:59     1052.0     9636.0    253.0  ...
# 1  10/1/2017 22:43  10/1/2017 22:43     1054.0     9637.0    254.0  ...
# 2  10/1/2017 22:50  10/1/2017 22:51     1054.0     9637.0    255.0  ...
# 3  10/1/2017 23:52  10/1/2017 23:52     1062.0     9642.0    256.0  ...
# 4   10/1/2017 2:13   10/1/2017 2:13     1050.0     9645.0    246.0  ...
# 5   10/1/2017 2:47   10/1/2017 2:47     1050.0     9644.0    247.0  ...
# 6   10/1/2017 2:48   10/1/2017 2:48     1050.0     9644.0    248.0  ...
# 7   10/1/2017 2:52   10/1/2017 2:53     1050.0     9644.0    249.0  ...
# 8   10/1/2017 3:47   10/1/2017 3:47     1050.0     9646.0    250.0  ...
# 9   10/1/2017 3:51   10/1/2017 3:51     1050.0     9646.0    251.0  ...
#
#   account_category new_june_2018  alt_external_id      tweet_id  \
# 0       RightTroll           0.0     9.058747e+17  9.145804e+17
# 1       RightTroll           0.0     9.058747e+17  9.146218e+17
# 2       RightTroll           0.0     9.058747e+17  9.146235e+17
# 3       RightTroll           0.0     9.058747e+17  9.146391e+17
# 4       RightTroll           0.0     9.058747e+17  9.143122e+17
# 5       RightTroll           0.0     9.058747e+17  9.143208e+17
# 6       RightTroll           0.0     9.058747e+17  9.143212e+17
# 7       RightTroll           0.0     9.058747e+17  9.143222e+17
# 8       RightTroll           0.0     9.058747e+17  9.143358e+17
# 9       RightTroll           0.0     9.058747e+17  9.143369e+17
#
#                                          article_url  \
# 0  http://twitter.com/905874659358453760/statuses...
# 1  http://twitter.com/905874659358453760/statuses...
# 2  http://twitter.com/905874659358453760/statuses...
# 3  http://twitter.com/905874659358453760/statuses...
# 4  http://twitter.com/905874659358453760/statuses...
# 5  http://twitter.com/905874659358453760/statuses...
# 6  http://twitter.com/905874659358453760/statuses...
# 7  http://twitter.com/905874659358453760/statuses...
# 8  http://twitter.com/905874659358453760/statuses...
# 9  http://twitter.com/905874659358453760/statuses...
#
#                                           tco1_step1  tco2_step1 tco3_step1  \
# 0  https://twitter.com/10_gop/status/914580356430...           0          0
# 1  https://twitter.com/damienwoody/status/9145685...           0          0
# 2  https://twitter.com/10_gop/status/913231923715...           0          0
# 3  https://twitter.com/10_gop/status/914639143690...           0          0
# 4  https://twitter.com/realDonaldTrump/status/914...           0          0
# 5  https://twitter.com/FoxNews/status/91423949678...           0          0
# 6  https://twitter.com/Cernovich/status/914314644...           0          0
# 7                                                  0           0          0
# 8  http://www.cnn.com/2017/09/27/us/puerto-rico-a...           0          0
# 9                                                  0           0          0
#
#    polarity subjectivity
# 0  0.050000     0.100000
# 1 -0.400000     0.400000
# 2  0.300000     1.000000
# 3  0.000000     0.000000
# 4  0.000000     0.000000
# 5  0.406250     0.375000
# 6  0.000000     0.000000
# 7 -0.155556     0.288889
# 8 -0.800000     0.900000
# 9  0.000000     0.333333
#
# [10 rows x 23 columns]

# %%
le = LabelEncoder()
df['account_category'] = le.fit_transform(df['account_category'].astype(str))
labels = df['account_category']

# %%
print(df.dtypes)
# Out:
# external_author_id      int64
# author                 object
# content                object
# region                 object
# language               object
# publish_date           object
# harvested_date         object
# following             float64
# followers             float64
# updates               float64
# post_type              object
# account_type           object
# retweet               float64
# account_category        int64
# new_june_2018         float64
# alt_external_id       float64
# tweet_id              float64
# article_url            object
# tco1_step1             object
# tco2_step1             object
# tco3_step1             object
# polarity              float64
# subjectivity          float64
# dtype: object

# %%
feats = ['polarity', 
         'subjectivity']
features = df[feats]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=0)

# %%
clf.fit(X_train, y_train)
preds = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, preds)
# Out:
# 0.8639813193228254

# %%
import matplotlib.pyplot as plt
import seaborn as sns
feats = {} 
for feature, importance in zip(X_train.columns, sorted(clf.feature_importances_, reverse=True)[:7]):
    feats[feature] = importance 

# graph
bar = pd.DataFrame.from_dict(feats, orient='index')
bar['index'] = bar.index.tolist()
plt.figure(figsize=(8,8))
ax = sns.barplot(x=0, y='index',data=bar)
ax.set(xlabel='Percentage', ylabel='Feature', title="Feature Importance")
plt.show()

# %% [markdown]
# Now, let's look at a sample from our database

# %%
sample = pd.read_csv('../data/data.csv')
sample.dropna(inplace=True)
print(sample.shape)
print(sample.dtypes)
# Out:
# (39522, 10)
# id               int64
# name            object
# screen_name     object
# description     object
# date_created    object
# followers        int64
# following        int64
# last_updated    object
# image_url       object
# is_bot          object
# dtype: object

# %% [markdown]
# Populate `is_bot` with random values

# %%
import random
vals = ['NOT', 'BOT', 'UNKNOWN']
sample['category'] = [random.choice(vals) for k in sample.index]

# %%
sample.head(10)
# Out:
#         id                 name    screen_name  \
# 0    74013              CJ n TX        ccjones
# 1   681403         Jason Benway      BenwayNet
# 2   736463  Won Peace of a Hole        dtweete
# 3   755703            Dean Roth       deanroth
# 4   759066        David Neuland       Galloway
# 5   759251                  CNN            CNN
# 6   796409         Steve Spinks  StevenMSpinks
# 7   810600              mzchief        mzchief
# 8   813286         Barack Obama    BarackObama
# 9  1053931            Roy Bragg       roybragg
#
#                                          description         date_created  \
# 0                           Nothing is as it seems.   2006-12-16 18:21:51
# 1  Christian,husband,father,Computer geek, and xb...  2007-01-22 16:42:28
# 2  probably a bot.                                 ✝  2007-01-31 07:20:08
# 3  See that name up there? That's me. \n\nAlso av...  2007-02-07 04:13:21
# 4  Engineer, writer, Mac-addict. I. Am. Not. Geor...  2007-02-08 23:18:36
# 5  It’s our job to #GoThere & tell the most diffi...  2007-02-09 00:35:02
# 6  Article V of the Constitution supplies the rem...  2007-02-26 23:55:57
# 7  Everyone has some issue, it is how we deal wit...  2007-03-04 19:28:27
# 8                  Dad, husband, President, citizen.  2007-03-05 22:08:25
# 9  I do nothing & try to avoid anything b/c it mi...  2007-03-12 23:47:18
#
#    followers  following         last_updated  \
# 0       3918       3398  2019-04-13 08:10:57
# 1       1068       1560  2019-04-15 00:32:18
# 2        624       1610  2019-04-14 06:21:22
# 3        649        790  2019-04-13 16:11:00
# 4        173        458  2019-04-14 04:50:49
# 5   41555368       1110  2019-03-20 14:42:04
# 6       3150       4126  2019-04-14 02:24:58
# 7         65        160  2019-04-14 13:41:10
# 8  105228666     615149  2019-03-20 04:05:08
# 9       3281        153  2019-04-15 14:34:32
#
#                                            image_url   is_bot category
# 0  http://pbs.twimg.com/profile_images/1060243585...  unknown      NOT
# 1  http://pbs.twimg.com/profile_images/1111705638...  unknown      NOT
# 2  http://pbs.twimg.com/profile_images/149195479/...  unknown      NOT
# 3  http://pbs.twimg.com/profile_images/4706719918...  unknown      BOT
# 4  http://pbs.twimg.com/profile_images/22917772/I...  unknown  UNKNOWN
# 5  http://pbs.twimg.com/profile_images/5089607618...  unknown      BOT
# 6  http://pbs.twimg.com/profile_images/1108452822...  unknown  UNKNOWN
# 7  http://pbs.twimg.com/profile_images/191610065/...  unknown      BOT
# 8  http://pbs.twimg.com/profile_images/8225477323...  unknown      BOT
# 9  http://pbs.twimg.com/profile_images/1039925325...  unknown      NOT

# %%
# calculate follower-following ratio
def calculate_f2f(row):
    try:
        val = row['followers'] / row['following']
    except ZeroDivisionError:
        val = 9999999999999
    return val

sample['f2f'] = sample.apply (lambda row: calculate_f2f(row), axis=1)

# %%
sample.head(4)
# Out:
#        id                 name screen_name  \
# 0   74013              CJ n TX     ccjones
# 1  681403         Jason Benway   BenwayNet
# 2  736463  Won Peace of a Hole     dtweete
# 3  755703            Dean Roth    deanroth
#
#                                          description         date_created  \
# 0                           Nothing is as it seems.   2006-12-16 18:21:51
# 1  Christian,husband,father,Computer geek, and xb...  2007-01-22 16:42:28
# 2  probably a bot.                                 ✝  2007-01-31 07:20:08
# 3  See that name up there? That's me. \n\nAlso av...  2007-02-07 04:13:21
#
#    followers  following         last_updated  \
# 0       3918       3398  2019-04-13 08:10:57
# 1       1068       1560  2019-04-15 00:32:18
# 2        624       1610  2019-04-14 06:21:22
# 3        649        790  2019-04-13 16:11:00
#
#                                            image_url   is_bot category  \
# 0  http://pbs.twimg.com/profile_images/1060243585...  unknown      NOT
# 1  http://pbs.twimg.com/profile_images/1111705638...  unknown      NOT
# 2  http://pbs.twimg.com/profile_images/149195479/...  unknown      NOT
# 3  http://pbs.twimg.com/profile_images/4706719918...  unknown      BOT
#
#         f2f
# 0  1.153031
# 1  0.684615
# 2  0.387578
# 3  0.821519

# %%
# check if description for account contains 'bot', 'parody' or 'fake'
def guess_if_bot(row):
    _str = row['description'].lower() + row['screen_name'].lower()
    flag = 0
    bot_words = ['bot', 'paroody', 'fake']
    if any(word in _str for word in bot_words):
        flag = 1
    return flag

sample['desc_bot'] = sample.apply(lambda row: guess_if_bot(row), axis = 1)
sample.head(5)
# Out:
#        id                 name screen_name  \
# 0   74013              CJ n TX     ccjones
# 1  681403         Jason Benway   BenwayNet
# 2  736463  Won Peace of a Hole     dtweete
# 3  755703            Dean Roth    deanroth
# 4  759066        David Neuland    Galloway
#
#                                          description         date_created  \
# 0                           Nothing is as it seems.   2006-12-16 18:21:51
# 1  Christian,husband,father,Computer geek, and xb...  2007-01-22 16:42:28
# 2  probably a bot.                                 ✝  2007-01-31 07:20:08
# 3  See that name up there? That's me. \n\nAlso av...  2007-02-07 04:13:21
# 4  Engineer, writer, Mac-addict. I. Am. Not. Geor...  2007-02-08 23:18:36
#
#    followers  following         last_updated  \
# 0       3918       3398  2019-04-13 08:10:57
# 1       1068       1560  2019-04-15 00:32:18
# 2        624       1610  2019-04-14 06:21:22
# 3        649        790  2019-04-13 16:11:00
# 4        173        458  2019-04-14 04:50:49
#
#                                            image_url   is_bot category  \
# 0  http://pbs.twimg.com/profile_images/1060243585...  unknown      NOT
# 1  http://pbs.twimg.com/profile_images/1111705638...  unknown      NOT
# 2  http://pbs.twimg.com/profile_images/149195479/...  unknown      NOT
# 3  http://pbs.twimg.com/profile_images/4706719918...  unknown      BOT
# 4  http://pbs.twimg.com/profile_images/22917772/I...  unknown  UNKNOWN
#
#         f2f  desc_bot
# 0  1.153031         0
# 1  0.684615         0
# 2  0.387578         1
# 3  0.821519         0
# 4  0.377729         0

# %%
# build random forest model
clf2 = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=0)
feats = ['f2f', 'desc_bot']
labs = ['category']
features = sample[feats]
labels = sample[labs]
X_train2, X_test2, y_train2, y_test2 = train_test_split(features, labels, test_size=0.33, random_state=42)
clf2.fit(X_train2, y_train2)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
pred = clf2.predict(X_test2)
accuracy_score(y_test2, pred)
# Out:
# 0.33121214444529634

# %% [markdown]
# This is probably pretty good for us since the values for the category were just randomly assigned. In the future, we will need to do this kind of identification based on the account's tweets

# %%
tweets = pd.read_csv('../data/tweets.csv')
tweets.dropna(inplace=True)
print(tweets.dtypes)
print(tweets.shape)
tweets.head(5)
# Out:
# created_at    object
# id_str         int64
# text          object
# user_id        int64
# dtype: object
# (145436, 4)
#             created_at               id_str  \
# 0  2018-06-04 10:51:53  1003590157038182400
# 1  2018-06-06 16:28:26  1004399626852724738
# 2  2018-06-08 11:22:34  1005047428876292096
# 3  2018-06-12 22:30:23  1006665040777314304
# 4  2018-06-19 05:51:23  1008950350181617664
#
#                                                 text             user_id
# 0  #WhereAreTheChildren #MAGA #QAnon #WWG1WGA @re...  943544870857256961
# 1                @realDonaldTrump God let's hope so!  741279278407417856
# 2          @realDonaldTrump That's a fact!!!!! #MAGA  741279278407417856
# 3                              @realDonaldTrump Lol!  741279278407417856
# 4  That's what all this traffic and cop cars and ...            65847626

# %%
import string
def remove_punct(row):
    s = row['text']
    return s.translate(str.maketrans('', '', string.punctuation))
tweets['text'] = tweets.apply(lambda row: remove_punct(row), axis = 1)

# %%
all_df = pd.merge(tweets, sample, left_on='user_id', right_on='id', how = 'left').drop('user_id', axis=1)
all_df.dropna(inplace=True)

# don't really care about when the status of an account is UNKNOWN
all_df = all_df[all_df['category'] != 'UNKNOWN']
print(all_df.shape)
all_df.head(5)
# Out:
# (76307, 16)
#              created_at               id_str  \
# 7   2018-06-26 22:35:14  1011739691953950720
# 9   2018-06-30 05:16:38  1012927872627904513
# 12  2018-07-12 16:21:40  1017443888666218496
# 22  2018-09-17 21:25:45  1041800399555112960
# 24  2018-09-22 19:44:00  1043586733521207298
#
#                                                  text            id  \
# 7   SecureTeam10 are you checking YouTube All comm...  9.471756e+17
# 9                         who is Q  Qanon MSM WWG1WGA  1.012797e+18
# 12  RT charliekirk11 I am now convinced that Democ...  1.183037e+09
# 22  RT TomBradysEgo Josh Gordon pulling up to Gill...  5.530687e+08
# 24  RT adviseagainstit tedcruz Am I the only one w...  2.700375e+08
#
#               name      screen_name  \
# 7          Eric 87       Inventor_Q
# 9   powerchairpete   powerchairpete
# 12           lovey  travelingthroug
# 22     Logan moore      L0ganmoore_
# 24     Brent Smith      jbsmith7845
#
#                                           description         date_created  \
# 7                    Thinker, Patriotic, and Inventor  2017-12-30 18:40:42
# 9                            make justice blind again  2018-06-29 20:37:36
# 12  #MAGA #Trump2020 #MICHIGAN  #DemocratsHateAmer...  2013-02-15 15:57:58
# 22                                         Dammit Jim  2012-04-13 20:27:11
# 24  A strict constitutionalist i believe the only ...  2011-03-21 21:58:57
#
#     followers  following         last_updated  \
# 7         4.0       28.0  2019-04-10 19:10:10
# 9         1.0        6.0  2019-04-14 14:42:05
# 12      612.0      785.0  2019-04-15 12:26:27
# 22      308.0      212.0  2019-04-14 02:20:21
# 24      128.0      664.0  2019-04-14 15:22:29
#
#                                             image_url   is_bot category  \
# 7   http://pbs.twimg.com/profile_images/1115745818...  unknown      BOT
# 9   http://pbs.twimg.com/profile_images/1117430572...  unknown      NOT
# 12  http://pbs.twimg.com/profile_images/9655721204...  unknown      NOT
# 22  http://pbs.twimg.com/profile_images/1008854461...  unknown      BOT
# 24  http://abs.twimg.com/sticky/default_profile_im...  unknown      BOT
#
#          f2f  desc_bot
# 7   0.142857       0.0
# 9   0.166667       0.0
# 12  0.779618       0.0
# 22  1.452830       0.0
# 24  0.192771       0.0

# %%
# add some weak NLP stuff 
from textblob import TextBlob
all_df[['polarity', 'subjectivity']] = all_df['text'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))

# %%
# build random forest model
clf3 = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=0)
feats = ['polarity', 'subjectivity', 'f2f', 'desc_bot']
labs = ['category']
features = all_df[feats]
labels = all_df[labs]
X_train2, X_test2, y_train2, y_test2 = train_test_split(features, labels, test_size=0.33, random_state=42)
clf3.fit(X_train2, y_train2)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
pred = clf3.predict(X_test2)
accuracy_score(y_test2, pred)
# Out:
# 0.5341513779683901
